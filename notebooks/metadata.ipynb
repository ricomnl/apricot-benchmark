# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %%
import json

import pandas as pd
from apricot import FeatureBasedSelection
from pmlb import fetch_data
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import train_test_split

from src.utils import *

# %%
pd.set_option("display.max_rows", 100)

# %%
pmlb_data = pd.read_csv("../metadata/Penn Machine Learning Benchmarks.csv")
# remove feynman datasets (119)
pmlb_data = pmlb_data[~pmlb_data["Dataset"].str.contains("feynman")]
# remove fri_c datasets (60)
pmlb_data = pmlb_data[~pmlb_data["Dataset"].str.contains("fri_c")]
# drop Metadata column
pmlb_data = pmlb_data.drop("Metadata", axis=1)
pmlb_data = pmlb_data.reset_index(drop=True)
# set categorical with n_classes == 2 to binary
pmlb_data.loc[pmlb_data["n_classes"] == 2, "Endpoint"] = "binary"

# %%
pmlb_data
# Out:
#                  Dataset  n_observations  n_features  n_classes     Endpoint  \
# 0                  adult           48842          14        2.0       binary
# 1       agaricus_lepiota            8145          22        2.0       binary
# 2                  allbp            3772          29        3.0  categorical
# 3               allhyper            3771          29        4.0  categorical
# 4                allhypo            3770          29        3.0  categorical
# ..                   ...             ...         ...        ...          ...
# 231  strogatz_shearflow1             400           2        NaN   continuous
# 232  strogatz_shearflow2             400           2        NaN   continuous
# 233        strogatz_vdp1             400           2        NaN   continuous
# 234        strogatz_vdp2             400           2        NaN   continuous
# 235              titanic            2201           3        NaN   continuous
#
#      Imbalance            Task
# 0         0.27  classification
# 1         0.00  classification
# 2         0.88  classification
# 3         0.93  classification
# 4         0.78  classification
# ..         ...             ...
# 231       0.00      regression
# 232       0.00      regression
# 233       0.00      regression
# 234       0.00      regression
# 235       0.13      regression
#
# [236 rows x 7 columns]

# %%
pmlb_data["feat_n_continuous"] = 0
pmlb_data["feat_n_categorical"] = 0
pmlb_data["feat_n_nominal"] = 0
pmlb_data["feat_n_binary"] = 0
pmlb_data["feat_n_ordinal"] = 0

for idx, dset in enumerate(pmlb_data["Dataset"].tolist()):
    m = load_metadata(dset)
    feats = {}
    for f in m["features"]:
        feats[f"feat_n_{f['type']}"] = feats.get(f"feat_n_{f['type']}", 0) + 1
    pmlb_data.loc[idx, feats.keys()] = feats.values()

# add nominal to categorical and remove categorical
pmlb_data["feat_n_categorical"] += pmlb_data["feat_n_nominal"]
pmlb_data = pmlb_data.drop(["feat_n_nominal"], axis=1)

# %%
pmlb_data[(pmlb_data["n_observations"] > 10_000) & (pmlb_data["n_observations"] < 500_000) & (pmlb_data["Task"] == "classification")]
# Out:
#        Dataset  n_observations  n_features  n_classes     Endpoint  Imbalance  \
# 0        adult           48842          14        2.0       binary       0.27
# 51   connect_4           67557          42        3.0  categorical       0.25
# 62        fars          100968          29        8.0  categorical       0.16
# 89      kddcup          494020          41       23.0  categorical       0.38
# 91      krkopt           28056           6       18.0  categorical       0.05
# 95      letter           20000          16       26.0  categorical       0.00
# 98       magic           19020          10        2.0       binary       0.09
# 105      mnist           70000         784       10.0  categorical       0.00
# 115    nursery           12958           8        4.0  categorical       0.09
# 120  pendigits           10992          16       10.0  categorical       0.00
# 135    shuttle           58000           9        7.0  categorical       0.59
# 136      sleep          105908          13        5.0  categorical       0.15
#
#                Task  feat_n_continuous  feat_n_categorical  feat_n_binary  \
# 0    classification                  6                   6              1
# 51   classification                  0                  42              0
# 62   classification                 14                  15              0
# 89   classification                 28                   9              4
# 91   classification                  0                   6              0
# 95   classification                 16                   0              0
# 98   classification                 10                   0              0
# 105  classification                654                 111             19
# 115  classification                  0                   7              1
# 120  classification                 16                   0              0
# 135  classification                  9                   0              0
# 136  classification                 12                   1              0
#
#      feat_n_ordinal
# 0                 1
# 51                0
# 62                0
# 89                0
# 91                0
# 95                0
# 98                0
# 105               0
# 115               0
# 120               0
# 135               0
# 136               0

# %%
result_df = pd.read_json("../results/results.json")

# %%
result_df.merge(pmlb_data, left_on="dataset", right_on="Dataset")
# Out:
#       dataset  fraction     score  most_prevalent_cls  least_prevalent_cls  \
# 0       adult    1.0000  0.800262            0.760718             0.239282
# 1       adult    0.0010  0.259029            0.583333             0.416667
# 2       adult    0.0010  0.721235            0.722222             0.277778
# 3       adult    0.0025  0.785767            0.516484             0.483516
# 4       adult    0.0025  0.799116            0.670330             0.329670
# 5       adult    0.0010  0.259029            0.583333             0.416667
# 6       adult    0.0010  0.721235            0.722222             0.277778
# 7       adult    0.0025  0.785767            0.516484             0.483516
# 8       adult    0.0025  0.799116            0.670330             0.329670
# 9       adult    0.0010  0.382524            0.638889             0.361111
# 10      adult    0.0010  0.678323            0.777778             0.222222
# 11      adult    0.0025  0.786095            0.538462             0.461538
# 12      adult    0.0025  0.797560            0.604396             0.395604
# 13  connect_4    1.0000  0.756187            0.658303             0.095460
# 14  connect_4    0.0010  0.494435            0.520000             0.220000
# 15  connect_4    0.0010  0.620722            0.620000             0.180000
# 16  connect_4    0.0025  0.530847            0.555556             0.190476
# 17  connect_4    0.0025  0.662049            0.619048             0.150794
# 18  connect_4    0.0010  0.550799            0.640000             0.140000
# 19  connect_4    0.0010  0.620722            0.620000             0.180000
# 20  connect_4    0.0025  0.511308            0.571429             0.206349
# 21  connect_4    0.0025  0.659088            0.634921             0.134921
# 22  connect_4    0.0010  0.605684            0.640000             0.080000
# 23  connect_4    0.0010  0.649082            0.700000             0.100000
# 24  connect_4    0.0025  0.647780            0.642857             0.150794
# 25  connect_4    0.0025  0.653286            0.626984             0.134921
# 26       fars    1.0000  0.784407            0.417122             0.000089
# 27       fars    0.0010  0.091237            0.466667             0.013333
# 28     kddcup    1.0000  0.972139            0.568378             0.000004
# 29     kddcup    0.0010  0.764447            0.637838             0.005405
# 30     krkopt    1.0000  0.394497            0.162283             0.000962
# 31     krkopt    0.0010  0.143142            0.190476             0.047619
# 32     krkopt    0.0010  0.155546            0.190476             0.047619
# 33     krkopt    0.0025  0.165526            0.192308             0.019231
# 34     krkopt    0.0025  0.200314            0.192308             0.019231
# 35     letter    1.0000  0.765200            0.040650             0.036700
# 36     letter    0.0010  0.077000            0.466667             0.066667
# 37     letter    0.0010  0.165600            0.200000             0.066667
# 38     letter    0.0025  0.090200            0.324324             0.027027
# 39     letter    0.0025  0.302600            0.081081             0.027027
# 40      magic    1.0000  0.798528            0.648370             0.351630
# 41    nursery    1.0000  0.929321            0.333385             0.025313
# 42    nursery    0.0010  0.460802            0.444444             0.222222
# 43    nursery    0.0010  0.581173            0.333333             0.333333
# 44    nursery    0.0025  0.684568            0.416667             0.250000
# 45    nursery    0.0025  0.773457            0.375000             0.291667
# 46  pendigits    1.0000  0.945779            0.104076             0.095979
# 47  pendigits    0.0010  0.295488            0.375000             0.125000
# 48  pendigits    0.0010  0.550218            0.250000             0.125000
# 49  pendigits    0.0025  0.311863            0.350000             0.100000
# 50  pendigits    0.0025  0.800582            0.150000             0.050000
# 51    shuttle    1.0000  0.959241            0.785966             0.000172
# 52    shuttle    0.0010  0.006138            0.418605             0.046512
# 53    shuttle    0.0010  0.924483            0.511628             0.046512
# 54    shuttle    0.0025  0.057241            0.703704             0.009259
# 55    shuttle    0.0025  0.937931            0.555556             0.009259
# 56      sleep    1.0000  0.736753            0.497583             0.085470
# 57      sleep    0.0010  0.421498            0.772152             0.025316
# 58      sleep    0.0010  0.606375            0.556962             0.025316
# 59      sleep    0.0025  0.497602            0.712121             0.015152
# 60      sleep    0.0025  0.666616            0.565657             0.035354
#
#             function   optimizer    Dataset  n_observations  n_features  \
# 0                NaN         NaN      adult           48842          14
# 1       featurebased       naive      adult           48842          14
# 2   facilitylocation       naive      adult           48842          14
# 3       featurebased       naive      adult           48842          14
# 4   facilitylocation       naive      adult           48842          14
# 5       featurebased        lazy      adult           48842          14
# 6   facilitylocation        lazy      adult           48842          14
# 7       featurebased        lazy      adult           48842          14
# 8   facilitylocation        lazy      adult           48842          14
# 9       featurebased  stochastic      adult           48842          14
# 10  facilitylocation  stochastic      adult           48842          14
# 11      featurebased  stochastic      adult           48842          14
# 12  facilitylocation  stochastic      adult           48842          14
# 13               NaN         NaN  connect_4           67557          42
# 14      featurebased       naive  connect_4           67557          42
# 15  facilitylocation       naive  connect_4           67557          42
# 16      featurebased       naive  connect_4           67557          42
# 17  facilitylocation       naive  connect_4           67557          42
# 18      featurebased        lazy  connect_4           67557          42
# 19  facilitylocation        lazy  connect_4           67557          42
# 20      featurebased        lazy  connect_4           67557          42
# 21  facilitylocation        lazy  connect_4           67557          42
# 22      featurebased  stochastic  connect_4           67557          42
# 23  facilitylocation  stochastic  connect_4           67557          42
# 24      featurebased  stochastic  connect_4           67557          42
# 25  facilitylocation  stochastic  connect_4           67557          42
# 26               NaN         NaN       fars          100968          29
# 27      featurebased       naive       fars          100968          29
# 28               NaN         NaN     kddcup          494020          41
# 29      featurebased        lazy     kddcup          494020          41
# 30               NaN         NaN     krkopt           28056           6
# 31      featurebased        lazy     krkopt           28056           6
# 32  facilitylocation        lazy     krkopt           28056           6
# 33      featurebased        lazy     krkopt           28056           6
# 34  facilitylocation        lazy     krkopt           28056           6
# 35               NaN         NaN     letter           20000          16
# 36      featurebased        lazy     letter           20000          16
# 37  facilitylocation        lazy     letter           20000          16
# 38      featurebased        lazy     letter           20000          16
# 39  facilitylocation        lazy     letter           20000          16
# 40               NaN         NaN      magic           19020          10
# 41               NaN         NaN    nursery           12958           8
# 42      featurebased        lazy    nursery           12958           8
# 43  facilitylocation        lazy    nursery           12958           8
# 44      featurebased        lazy    nursery           12958           8
# 45  facilitylocation        lazy    nursery           12958           8
# 46               NaN         NaN  pendigits           10992          16
# 47      featurebased        lazy  pendigits           10992          16
# 48  facilitylocation        lazy  pendigits           10992          16
# 49      featurebased        lazy  pendigits           10992          16
# 50  facilitylocation        lazy  pendigits           10992          16
# 51               NaN         NaN    shuttle           58000           9
# 52      featurebased        lazy    shuttle           58000           9
# 53  facilitylocation        lazy    shuttle           58000           9
# 54      featurebased        lazy    shuttle           58000           9
# 55  facilitylocation        lazy    shuttle           58000           9
# 56               NaN         NaN      sleep          105908          13
# 57      featurebased        lazy      sleep          105908          13
# 58  facilitylocation        lazy      sleep          105908          13
# 59      featurebased        lazy      sleep          105908          13
# 60  facilitylocation        lazy      sleep          105908          13
#
#     n_classes     Endpoint  Imbalance            Task  feat_n_continuous  \
# 0         2.0       binary       0.27  classification                  6
# 1         2.0       binary       0.27  classification                  6
# 2         2.0       binary       0.27  classification                  6
# 3         2.0       binary       0.27  classification                  6
# 4         2.0       binary       0.27  classification                  6
# 5         2.0       binary       0.27  classification                  6
# 6         2.0       binary       0.27  classification                  6
# 7         2.0       binary       0.27  classification                  6
# 8         2.0       binary       0.27  classification                  6
# 9         2.0       binary       0.27  classification                  6
# 10        2.0       binary       0.27  classification                  6
# 11        2.0       binary       0.27  classification                  6
# 12        2.0       binary       0.27  classification                  6
# 13        3.0  categorical       0.25  classification                  0
# 14        3.0  categorical       0.25  classification                  0
# 15        3.0  categorical       0.25  classification                  0
# 16        3.0  categorical       0.25  classification                  0
# 17        3.0  categorical       0.25  classification                  0
# 18        3.0  categorical       0.25  classification                  0
# 19        3.0  categorical       0.25  classification                  0
# 20        3.0  categorical       0.25  classification                  0
# 21        3.0  categorical       0.25  classification                  0
# 22        3.0  categorical       0.25  classification                  0
# 23        3.0  categorical       0.25  classification                  0
# 24        3.0  categorical       0.25  classification                  0
# 25        3.0  categorical       0.25  classification                  0
# 26        8.0  categorical       0.16  classification                 14
# 27        8.0  categorical       0.16  classification                 14
# 28       23.0  categorical       0.38  classification                 28
# 29       23.0  categorical       0.38  classification                 28
# 30       18.0  categorical       0.05  classification                  0
# 31       18.0  categorical       0.05  classification                  0
# 32       18.0  categorical       0.05  classification                  0
# 33       18.0  categorical       0.05  classification                  0
# 34       18.0  categorical       0.05  classification                  0
# 35       26.0  categorical       0.00  classification                 16
# 36       26.0  categorical       0.00  classification                 16
# 37       26.0  categorical       0.00  classification                 16
# 38       26.0  categorical       0.00  classification                 16
# 39       26.0  categorical       0.00  classification                 16
# 40        2.0       binary       0.09  classification                 10
# 41        4.0  categorical       0.09  classification                  0
# 42        4.0  categorical       0.09  classification                  0
# 43        4.0  categorical       0.09  classification                  0
# 44        4.0  categorical       0.09  classification                  0
# 45        4.0  categorical       0.09  classification                  0
# 46       10.0  categorical       0.00  classification                 16
# 47       10.0  categorical       0.00  classification                 16
# 48       10.0  categorical       0.00  classification                 16
# 49       10.0  categorical       0.00  classification                 16
# 50       10.0  categorical       0.00  classification                 16
# 51        7.0  categorical       0.59  classification                  9
# 52        7.0  categorical       0.59  classification                  9
# 53        7.0  categorical       0.59  classification                  9
# 54        7.0  categorical       0.59  classification                  9
# 55        7.0  categorical       0.59  classification                  9
# 56        5.0  categorical       0.15  classification                 12
# 57        5.0  categorical       0.15  classification                 12
# 58        5.0  categorical       0.15  classification                 12
# 59        5.0  categorical       0.15  classification                 12
# 60        5.0  categorical       0.15  classification                 12
#
#     feat_n_categorical  feat_n_binary  feat_n_ordinal
# 0                    6              1               1
# 1                    6              1               1
# 2                    6              1               1
# 3                    6              1               1
# 4                    6              1               1
# 5                    6              1               1
# 6                    6              1               1
# 7                    6              1               1
# 8                    6              1               1
# 9                    6              1               1
# 10                   6              1               1
# 11                   6              1               1
# 12                   6              1               1
# 13                  42              0               0
# 14                  42              0               0
# 15                  42              0               0
# 16                  42              0               0
# 17                  42              0               0
# 18                  42              0               0
# 19                  42              0               0
# 20                  42              0               0
# 21                  42              0               0
# 22                  42              0               0
# 23                  42              0               0
# 24                  42              0               0
# 25                  42              0               0
# 26                  15              0               0
# 27                  15              0               0
# 28                   9              4               0
# 29                   9              4               0
# 30                   6              0               0
# 31                   6              0               0
# 32                   6              0               0
# 33                   6              0               0
# 34                   6              0               0
# 35                   0              0               0
# 36                   0              0               0
# 37                   0              0               0
# 38                   0              0               0
# 39                   0              0               0
# 40                   0              0               0
# 41                   7              1               0
# 42                   7              1               0
# 43                   7              1               0
# 44                   7              1               0
# 45                   7              1               0
# 46                   0              0               0
# 47                   0              0               0
# 48                   0              0               0
# 49                   0              0               0
# 50                   0              0               0
# 51                   0              0               0
# 52                   0              0               0
# 53                   0              0               0
# 54                   0              0               0
# 55                   0              0               0
# 56                   1              0               0
# 57                   1              0               0
# 58                   1              0               0
# 59                   1              0               0
# 60                   1              0               0

# %%
# adult    : some continuous, some categorical --> big difference
# connect_4: all categorical                   --> small difference
# krkopt   : all categorical                   --> small difference
# letter   : all continuous                    --> pretty big difference
# nursery  : all categorical                   --> not that big of a difference
# pendigits: all continuous                    --> pretty big difference
# shuttle  : all continuous                    --> pretty big difference
# sleep    : all continuous                    --> not that big of a difference

# %%
# time it takes to create the similarity matrix vs time it takes to execute the facility location
# what types of preprocessing work well to get the feature based function to work? for people who are new to submodular optimization
# run for all datasets, look at the biggest difference between feature based and facility location and pick these to try out different preprocessing steps (e.g. GMMs)
#     - mix of features
#     - pixels
#     - tabular data where feature distribution is meaningful

# take a random subset in with the same size as the apricot

# 1. two toy data sets: images (mnist, fashion mnist), other type of data
# old CV ways of feature extraction, use pretrained network to help (we can't guarantee that their output is non-negative)
# 2. apply ideas to large corpus of datasets
# 3. look at different optimizers

# Stratified K-fold: split dataset by classes, run SO on each class

# %%
dataset = "shuttle"
m = load_metadata(dataset)
X = fetch_data(dataset, local_cache_dir="../datasets")
categorical_fs = [f["name"] for f in m["features"] if f["type"] == "categorical"]
continuous_fs = [f["name"] for f in m["features"] if f["type"] == "continuous"]

# %%
# OHE categorical features
X = one_hot_encode_df(X, columns=categorical_fs)
# Standardize continuous features
X.loc[:, continuous_fs] = normalize_df(X, columns=continuous_fs)

# %%
y = X["target"]
X = X.drop("target", axis=1)

# %%
X.head()
# Out:
#          A1        A2        A3        A4        A5        A6        A7  \
# 0  0.232323  0.489289  0.437500  0.507015  0.346154  0.638117  0.490196
# 1  0.282828  0.487167  0.554688  0.507015  0.301282  0.638737  0.549020
# 2  0.262626  0.487167  0.476562  0.507015  0.384615  0.637997  0.503268
# 3  0.101010  0.487167  0.429688  0.507015  0.346154  0.638546  0.575163
# 4  0.101010  0.487167  0.453125  0.507015  0.355769  0.637496  0.594771
#
#          A8        A9
# 0  0.643660  0.607717
# 1  0.714286  0.662379
# 2  0.614767  0.575563
# 3  0.643660  0.585209
# 4  0.640449  0.575563

# %%
train_X, test_X, train_y, test_y = train_test_split(X.values, y.values)

# %%
fb_select1 = FeatureBasedSelection(n_samples=len(train_X)*0.1, optimizer="naive", verbose=True)
fb_select1.fit(train_X)
# Out:
# 100%|██████████| 4.35k/4.35k [00:19<00:00, 222it/s]

# %%
train_X_subset = train_X[fb_select1.ranking, :]
train_y_subset = train_y[fb_select1.ranking]

# %%
# model = LinearRegression()
model = LogisticRegression(max_iter=1000)

model_f = model
model_f.fit(train_X, train_y)
s_f = model_f.score(test_X, test_y)

model_s = model
model_s.fit(train_X_subset, train_y_subset)
s_s = model_s.score(test_X, test_y)

# %%
s_f, s_s
# Out:
# (0.09147355099967025, -0.03792401286276714)

# %%
pmlb_data.to_csv("../metadata/pmlb_data_processed.csv", index=None)
